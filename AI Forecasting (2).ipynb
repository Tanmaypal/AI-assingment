# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\TANMAY\\Downloads\\BAJAJ.csv")
df.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0  9/22/2017  3064.000000  3084.649902  3008.050049  3042.449951  2915.901367
# 1  9/25/2017  3058.399902  3058.399902  3004.800049  3044.100098  2917.482910
# 2  9/26/2017  3032.000000  3058.000000  3030.000000  3044.899902  2918.249268
# 3  9/27/2017  3055.199951  3066.000000  3007.000000  3031.250000  2905.167236
# 4  9/28/2017  3034.000000  3056.000000  3019.050049  3039.449951  2913.026123
#
#    Volume    Return
# 0  277811       NaN
# 1  412640  0.000542
# 2  210821  0.000263
# 3  271027 -0.004503
# 4  324106  0.002698

# %%
df1=df[['Date','Close','Return']]
df1.head()
# Out:
#         Date        Close    Return
# 0  9/22/2017  3042.449951       NaN
# 1  9/25/2017  3044.100098  0.000542
# 2  9/26/2017  3044.899902  0.000263
# 3  9/27/2017  3031.250000 -0.004503
# 4  9/28/2017  3039.449951  0.002698

# %%
returns = (df.Close - df.Close.shift(1))/df.Close.shift(1)
returns.head()
dreturns=pd.Series(returns)
dreturns
B1=returns.mean(axis=0)
A1=returns.std()
A1
B1
# Out:
# 3.935867423813374e-05

# %%
df2=df[['Return']]
df2.head()
# Out:
#      Return
# 0       NaN
# 1  0.000542
# 2  0.000263
# 3 -0.004503
# 4  0.002698

# %%
returns1 = ((df.Close - df.Close.shift(1)/df.Close.shift(1)))
returns1.head()
# Out:
# 0            NaN
# 1    3043.100098
# 2    3043.899902
# 3    3030.250000
# 4    3038.449951
# Name: Close, dtype: float64

# %%
dreturns1=pd.Series(returns1)
B=returns1.mean(axis=0)
A=returns1.std()
A
# Out:
# 213.41310632289748

# %%
B
# Out:
# 2891.862266732108

# %%
return3=(df.Close/df.Close.shift(1))
dreturns3=pd.Series(return3)
return3_log=np.log(dreturns3)
return3_log.mean(axis=0)
# Out:
# -7.75392192621642e-05

# %%
test=df.iloc[-5:]##Tking only the last five rows
test
# Out:
#           Date         Open         High          Low        Close  \
# 485  9/16/2019  2859.000000  2887.699951  2850.000000  2874.449951
# 486  9/17/2019  2874.800049  2875.850098  2762.550049  2773.149902
# 487  9/18/2019  2798.000000  2819.000000  2750.100098  2777.050049
# 488  9/19/2019  2773.000000  2776.000000  2721.449951  2738.850098
# 489  9/20/2019  2730.000000  3020.100098  2725.000000  2929.250000
#
#        Adj Close   Volume    Return
# 485  2874.449951   305963 -0.001305
# 486  2773.149902   439334 -0.036529
# 487  2777.050049   524048  0.001404
# 488  2738.850098   228796 -0.013947
# 489  2929.250000  1423536  0.065000

# %%
S_actual=2874.44
S_actual1=2773.14
S_actual2=2777.05
S_actual3=2738.85
S_actual4=2929.25

# %%
train=df.iloc[0:-5]###leaving the last five rows
train.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0  9/22/2017  3064.000000  3084.649902  3008.050049  3042.449951  2915.901367
# 1  9/25/2017  3058.399902  3058.399902  3004.800049  3044.100098  2917.482910
# 2  9/26/2017  3032.000000  3058.000000  3030.000000  3044.899902  2918.249268
# 3  9/27/2017  3055.199951  3066.000000  3007.000000  3031.250000  2905.167236
# 4  9/28/2017  3034.000000  3056.000000  3019.050049  3039.449951  2913.026123
#
#    Volume    Return
# 0  277811       NaN
# 1  412640  0.000542
# 2  210821  0.000263
# 3  271027 -0.004503
# 4  324106  0.002698

# %%
df2.mean(axis=0)
# Out:
# Return   -0.000195
# dtype: float64

# %%
df2.std(axis=0)
# Out:
# Return    0.015357
# dtype: float64

# %%
S=train.Close.tail(1)
S0=2878.199951
S0
# Out:
# 2878.199951

# %%
import numpy as np
S1=S0*(exp(B1-(A1*A1)/2) + A1*np.random.normal())
S1
# Out:
# 2806.4157149401985

# %%
S2=S1*(exp(B1-(A1*A1)/2) + A1*np.random.normal())
S2
# Out:
# 2871.1616474326293

# %%
S3=S2*(exp(B1-(A1*A1)/2) + A1*np.random.normal())
S3
# Out:
# 2873.602497839416

# %%
S4=S3*(exp(B1-(A1*A1)/2) + A1*np.random.normal())
S4
# Out:
# 2812.6715042745695

# %%
S5=S4*(exp(B1-(A1*A1)/2) + A1*np.random.normal())
S5
# Out:
# 2854.0579686668284

# %%
from math import exp

# %%
B
# Out:
# 2891.862266732108

# %%
listp = [[], [], [], [], []]

for i in range(1000):
    S1=S0*(exp(B1-(A1*A1)/2) + A1*np.random.normal())
    listp[0].append(S1)
    S2=S1*(exp(B1-(A1*A1)/2) + A1*np.random.normal())
    listp[1].append(S2)
    S3=S2*(exp(B1-(A1*A1)/2) + A1*np.random.normal())
    listp[2].append(S3)
    S4=S3*(exp(B1-(A1*A1)/2) + A1*np.random.normal())
    listp[3].append(S4)
    S5=S4*(exp(B1-(A1*A1)/2) + A1*np.random.normal())
    listp[4].append(S5)

# %%
listp
# Out:
# [[2846.85263919659,
#   2950.520834587679,
#   2863.4573962102777,
#   2820.9722846425952,
#   2838.1466042070224,
#   2902.849340127843,
#   2835.1458524260315,
#   2817.915403014079,
#   2916.8950744899375,
#   2854.373534300372,
#   2884.5748904186544,
#   2905.4220201992066,
#   2935.690028147242,
#   2826.845725529654,
#   2862.0486587298237,
#   2915.2778366116036,
#   2922.1177134747127,
#   2858.1625343601645,
#   2905.9560604256667,
#   2808.7641839949665,
#   2869.0846789710904,
#   2859.8787877225436,
#   2960.074894604053,
#   2873.1850375538224,
#   2947.1591564901123,
#   2897.0195190040868,
#   2939.1204483308707,
#   2863.0752946931198,
#   2960.2708193189724,
#   2901.790610005348,
#   2832.378687690488,
#   2825.1928616637065,
#   2874.2319778581964,
#   2816.1842745199715,
#   2812.5698292685324,
#   2878.3359831115094,
#   2897.1677397912754,
#   2826.66145673327,
#   2839.0908925261906,
#   2819.607071004556,
#   2846.299318425518,
#   2839.385104190122,
# ...

# %%
from statistics import mean

s1 = mean(listp[0])
s2 = mean(listp[1])
s3 = mean(listp[2])
s4 = mean(listp[3])
s5 = mean(listp[4])

# %%
s1
# Out:
# 2878.330865319864

# %%
s2
# Out:
# 2879.25075911269

# %%
Error=(s1 -S_actual)/S_actual
Error
# Out:
# 0.001353608118403631

# %%
Accuracy=1-Error
Accuracy
# Out:
# 0.8646391881596369

# %%
Error1=(s2 -S_actual1)/S_actual1
Error1
# Out:
# 0.03826375845167939

# %%
Accuracy1=1-Error1
Accuracy1
# Out:
# -2.826375845167939

# %%
Error2=(s3 -S_actual2)/S_actual2
Error2
# Out:
# 0.03682394858223244

# %%
Accuracy2=1-Error2
Accuracy2
# Out:
# 0.9631760514177675

# %%
Error3=(s4 -S_actual3)/S_actual3
Error3
# Out:
# 0.052183484611734283

# %%
Error4=(s4 -S_actual4)/S_actual4
Error4
# Out:
# -0.01620799288935791

# %%
Accuracy3=1-Error3
Accuracy3
# Out:
# 0.9478165153882657

# %%
Accuracy4=1-Error4
Accuracy4
# Out:
# 1.016207992889358

# %%
Accuracy_mean=(Accuracy+Accuracy1+Accuracy2+Accuracy3+Accuracy4)/5
Accuracy_mean
# Out:
# 0.19309278053741785
